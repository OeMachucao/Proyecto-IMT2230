# %% [markdown]
# # P1 ELECCION Y DESCRIPCION DEL CORPUS
# Para el desarrollo de este proyecto se selecciono un corpus compuesto por 60 documentos.La coleccion aborda el despligue tecnologico y la participacion de la empresa de analisis de datos Palantir Technologies en el contexto del conflicto de Gaza.
# El corpus ha sido balanceado estrategicamente en dos grandes vertientes discursivas :
#
#
#
# **1-Prensa y literatura técnica/militar**: Compuesta por comunicados oficiales de Palantir (entradas de blog sobre su plataforma AIP y sistemas de navegación visual), acuerdos corporativos y reportajes de medios especializados en defensa (como Defense News y C4ISRNET). Estos textos aportan una alta densidad de vocabulario enfocado en la eficiencia algorítmica, toma de decisiones automatizada y arquitectura de software.
#
#
#
#
# **2-Reportes éticos, legales y humanitarios**: Integrada por informes de organizaciones no gubernamentales (Amnistía Internacional, Business & Human Rights Resource Centre), ensayos académicos y artículos de prensa internacional crítica. Esta fracción aporta el lenguaje propio del derecho internacional, los derechos humanos y la rendición de cuentas ante el riesgo de bajas civiles.
#
# # NUESTRO INTERES SOBRE ESTE CORPUS
# El valor analítico de este conjunto de datos radica en la compleja tensión semántica que existe en la intersección entre la inteligencia artificial de vanguardia aplicada a la defensa nacional y el marco ético global. Desde la perspectiva del modelamiento matemático, resulta un caso de estudio idóneo para evaluar si la Descomposición en Valores Singulares (SVD) es capaz de capturar la estructura latente que separa el lenguaje puramente operativo y aséptico de la ingeniería de software, frente al discurso crítico y valorativo de los derechos humanos, o si, por el contrario, revela superposiciones semánticas entre ambos mundos.
#
# # P2 HIPOTESIS INICIAL
# Antes de aplicar la matemática (SVD) a nuestros textos, nuestra hipótesis es que el algoritmo va a separar los documentos en dos mundos muy distintos. Al reducir las dimensiones para poder graficar, esperamos ver dos grupos principales:
#
# **El grupo técnico:** Aquí deberían quedar los comunicados de Palantir y las noticias de tecnología militar. Esperamos que se agrupen alrededor de palabras "frías" y de ingeniería, como algoritmo, plataforma, IA, drones, datos y objetivos.
#
# **El grupo ético**: Aquí deberían caer los reportes de ONGs y las noticias críticas. Van a estar agrupados por palabras que hablan del impacto humano y las reglas del conflicto, como civiles, derechos humanos, privacidad, riesgo, leyes y bajas.
#
# También creemos que van a aparecer algunos textos "al medio" del gráfico. Esto pasaría con documentos como las respuestas oficiales de la empresa a las críticas o reportajes de investigación profundos, ya que son textos que están obligados a mezclar el lenguaje técnico con el lenguaje ético, sirviendo como un puente entre ambos mundos.
